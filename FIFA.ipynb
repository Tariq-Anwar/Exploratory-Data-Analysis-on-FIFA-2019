# %% [markdown]
# # Importing necessary library

# %% [markdown]
# Explorstory Data Analysis of FIFA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the data
df=pd.read_csv("E:/dataset/players_20.csv")

# %%
#this will display total columns in dataset
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  6/24/1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34   2/5/1985
# 2          Neymar Jr        Neymar da Silva Santos Junior   27   2/5/1992
# 3           J. Oblak                            Jan Oblak   26   1/7/1993
# 4          E. Hazard                          Eden Hazard   28   1/7/1991
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.title("Distribution of Age")
sns.distplot(df["age"])

# %%
df.head(1)
# Out:
#    sofifa_id                                         player_url short_name  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
#
#                         long_name  age        dob  height_cm  weight_kg  \
# 0  Lionel Andrés Messi Cuccittini   32  6/24/1987        170         72
#
#   nationality          club  overall  potential  value_eur  wage_eur  \
# 0   Argentina  FC Barcelona       94         94   95500000    565000
#
#   player_positions preferred_foot  international_reputation  weak_foot  \
# 0       RW, CF, ST           Left                         5          4
#
#    skill_moves   work_rate body_type real_face  release_clause_eur  \
# 0            4  Medium/Low     Messi       Yes         195800000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
#
#    team_jersey_number loaned_from    joined  contract_valid_until  \
# ...

# %%
taken_columns=['short_name','age','nationality','overall','potential','club','value_eur','wage_eur','player_positions','preferred_foot','international_reputation','weak_foot','skill_moves','work_rate','body_type','team_position','height_cm','weight_kg','pace','shooting','passing','dribbling','defending','physic','player_traits','attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys']

# %%
df=pd.DataFrame(df,columns=taken_columns)

# %%
df.head()
# Out:
#           short_name  age nationality  overall  potential  \
# 0           L. Messi   32   Argentina       94         94
# 1  Cristiano Ronaldo   34    Portugal       93         93
# 2          Neymar Jr   27      Brazil       92         92
# 3           J. Oblak   26    Slovenia       91         93
# 4          E. Hazard   28     Belgium       91         91
#
#                   club  value_eur  wage_eur player_positions preferred_foot  \
# 0         FC Barcelona   95500000    565000       RW, CF, ST           Left
# 1             Juventus   58500000    405000           ST, LW          Right
# 2  Paris Saint-Germain  105500000    290000          LW, CAM          Right
# 3      Atlético Madrid   77500000    125000               GK          Right
# 4          Real Madrid   90000000    470000           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# ...

# %%
df.shape
# Out:
# (18278, 30)

# %%
df.isnull().sum()
# Out:
# short_name                        0
# age                               0
# nationality                       0
# overall                           0
# potential                         0
# club                              0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# team_position                   240
# height_cm                         0
# weight_kg                         0
# pace                           2036
# shooting                       2036
# passing                        2036
# dribbling                      2036
# defending                      2036
# physic                         2036
# player_traits                 10712
# attacking_crossing                0
# ...

# %%
df["team_position"].value_counts()
# Out:
# SUB    7820
# RES    2958
# GK      662
# RCB     660
# LCB     660
# RB      560
# LB      560
# ST      458
# RCM     411
# LCM     411
# RM      399
# LM      398
# CAM     311
# RDM     244
# LDM     242
# RS      195
# LS      195
# CDM     181
# LW      162
# RW      161
# CB      100
# CM       76
# LWB      58
# RWB      58
# LAM      23
# RAM      23
# RF       19
# LF       19
# CF       14
# Name: team_position, dtype: int64

# %%
#The describe() method shows a summary of the numerical attributes
df.describe()
# Out:
#                 age       overall     potential     value_eur       wage_eur  \
# count  18278.000000  18278.000000  18278.000000  1.827800e+04   18278.000000
# mean      25.283291     66.244994     71.546887  2.484038e+06    9456.942773
# std        4.656964      6.949953      6.139669  5.585481e+06   21351.714095
# min       16.000000     48.000000     49.000000  0.000000e+00       0.000000
# 25%       22.000000     62.000000     67.000000  3.250000e+05    1000.000000
# 50%       25.000000     66.000000     71.000000  7.000000e+05    3000.000000
# 75%       29.000000     71.000000     75.000000  2.100000e+06    8000.000000
# max       42.000000     94.000000     95.000000  1.055000e+08  565000.000000
#
#        international_reputation     weak_foot   skill_moves     height_cm  \
# count              18278.000000  18278.000000  18278.000000  18278.000000
# mean                   1.103184      2.944250      2.368038    181.362184
# ...

# %% [markdown]
# Analysis

# %% [markdown]
#  1. We try to find out which countries have the most number of players in the game

# %%
print('Total Number of Country : {0}'.format(df['nationality'].nunique()))
print(df['nationality'].value_counts().head())
# Out:
# Total Number of Country : 162
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %% [markdown]
# Visualization of Data

# %%
sns.countplot(y='nationality',data=df,order=df.nationality.value_counts().iloc[:10].index)

# %% [markdown]
# 2. club with more no of players

# %%
print('Total Number of Club : {0}'.format(df['club'].nunique()))
print(df['club'].value_counts().head())
# Out:
# Total Number of Club : 698
# Paris Saint-Germain    33
# Leicester City         33
# CD Leganés             33
# Crystal Palace         33
# Chelsea                33
# Name: club, dtype: int64

# %% [markdown]
# visualization of data

# %%
sns.countplot(y=df.club.value_counts(),data=df)

# %% [markdown]
# 3. Effect of Age on player's wage

# %%
Mean_wage_per_age=df.groupby('age')['wage_eur'].mean()

# %%
 Mean_wage_per_age
# Out:
# age
# 16     1083.333333
# 17     1074.235808
# 18     1760.937500
# 19     2813.056380
# 20     4080.994387
# 21     5052.363636
# 22     7386.583679
# 23     8267.304860
# 24     9042.438272
# 25    11111.448067
# 26    12140.944882
# 27    13243.202417
# 28    14522.099448
# 29    13494.494494
# 30    13215.175538
# 31    13339.529120
# 32    15949.748744
# 33    12991.578947
# 34    13146.179402
# 35     7432.258065
# 36     6290.076336
# 37     5555.555556
# 38     5571.428571
# 39     3250.000000
# 40     3692.307692
# 41    21250.000000
# 42     3000.000000
# Name: wage_eur, dtype: float64

# %%
plt=sns.barplot(x= Mean_wage_per_age.index,y=Mean_wage_per_age.values)

# %%
talents_df=df.filter(["short_name","club","overall"])
talents_df = talents_df[talents_df.overall>=85]
talents_df = talents_df.groupby("club").count()
talents_df = talents_df.sort_values(by=['short_name'],ascending=False)
top_ten_clubs = talents_df[:10]
top_ten_clubs = list(top_ten_clubs.index.values)
top_count =  list(talents_df.iloc[:, 1])

# %%
top_ten_clubs
# Out:
# ['Real Madrid',
#  'FC Barcelona',
#  'Juventus',
#  'Manchester City',
#  'FC Bayern München',
#  'Paris Saint-Germain',
#  'Liverpool',
#  'Tottenham Hotspur',
#  'Inter',
#  'Napoli']

# %%
top_ten_clubs_data = df.loc[df['club'].isin(top_ten_clubs), :]

# %% [markdown]
# 4. Wages budget compare across top clubs

# %% [markdown]
# FC Barcelona and Real Madrid have the highest wage budgets, followed closely by Juventus and Manchester City

# %%
ax = sns.barplot(x = "club",y = "wage_eur",data = top_ten_clubs_data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40)
# Out:
# [Text(0, 0, 'FC Barcelona'),
#  Text(0, 0, 'Juventus'),
#  Text(0, 0, 'Paris Saint-Germain'),
#  Text(0, 0, 'Real Madrid'),
#  Text(0, 0, 'Manchester City'),
#  Text(0, 0, 'Liverpool'),
#  Text(0, 0, 'Napoli'),
#  Text(0, 0, 'Tottenham Hotspur'),
#  Text(0, 0, 'FC Bayern München'),
#  Text(0, 0, 'Inter')]

# %% [markdown]
# 5. Market values of players compare across top clubs.

# %%
sns.set(style="white")
p = sns.boxplot(x = 'club', y = 'value_eur', data = top_ten_clubs_data)

# %% [markdown]
# Spain, Brazil and Argentina have the players with highest overall scores

# %%
top_ten_countries = df['nationality'].value_counts().head(10).index.values
top_ten_countries_data = df.loc[df['nationality'].isin(top_ten_countries), :]
p = sns.boxplot(x = 'nationality', y = 'overall', data = top_ten_countries_data)

# %%
sns.jointplot(x=df['age'],y=df['potential'],
              joint_kws={'alpha':0.1,'s':5,'color':'b'},
              marginal_kws={'color':"b"})

# %%
df['preferred_foot'].value_counts()
# Out:
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64

# %%
x=df[df['preferred_foot']=="Left"][["short_name","overall"]].head()

# %%
x
# Out:
#       short_name  overall
# 0       L. Messi       94
# 9       M. Salah       90
# 16  G. Chiellini       89
# 22  A. Griezmann       89
# 23     P. Dybala       88

# %%
y=df[df['preferred_foot'] == 'Right'][['short_name','overall']].head()

# %%
y
# Out:
#           short_name  overall
# 1  Cristiano Ronaldo       93
# 2          Neymar Jr       92
# 3           J. Oblak       91
# 4          E. Hazard       91
# 5       K. De Bruyne       91

# %%
import matplotlib.pyplot as plt
corr=df.corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_features].corr(),annot=True)
